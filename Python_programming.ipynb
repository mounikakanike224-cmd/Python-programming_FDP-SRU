# %% [markdown]
# <a href="https://colab.research.google.com/github/mounikakanike224-cmd/Python-programming_FDP-SRU/blob/main/Python_programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Day-1**

# %%
import keyword
print("standard keywords=",len(keyword.kwlist))
print("soft keywords=",keyword.softkwlist)
print("all keywords=",keyword.kwlist)
# Out:
# standard keywords= 35
# soft keywords= ['_', 'case', 'match', 'type']
# all keywords= ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
x=5
y="python"
z=3.5
print(x)
print(y)
print(z)
# Out:
# 5
# python
# 3.5

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
y1=2
print(y1)
print(type(y1))

y2=float(y1)
print(y2)
print(type(y2))

y3=str(y1)
print(y3)
print(type(y3))
# Out:
# 2
# <class 'int'>
# 2.0
# <class 'float'>
# 2
# <class 'str'>

# %%
y1=int(2)
y2=float(2)
y3=str(2)

print(y1)
print(y2)
print(y3)

print(type(y1))
print(type(y2))
print(type(y3))
# Out:
# 2
# 2.0
# 2
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
c=50
d=float(c)


'''what is the data type of variable d? for commenting using sigle colon if comment line is more than one line three colons'''

print (type(d))
# Out:
# <class 'float'>

# %%
myname="mounika"
my_dept="EEE"
_my univ="SRU"
myLoc="TS"
myLOC="hyd"
# Out:
#   File "/tmp/ipykernel_2693/2932833408.py", line 3
#     _my univ="SRU"
#         ^
# SyntaxError: invalid syntax

# %%
myname="mounika"
my_dept="EEE"
_my_univ="SRU"
myLoc="TS"
myLOC="hyd"
mydep2="EEE2"

print(myname)
print(my_dept)
print(_my_univ)
print(myLoc)
print(myLOC)
print(mydep2)
# Out:
# mounika
# EEE
# SRU
# TS
# hyd
# EEE2

# %%
a=input("enter value of a")
b=input("enter value of b")
print("============")
print("sample calculator")
print("============")
print("addition="a+b)
print("============")



c=a+b
print(c)
# Out:
#   File "/tmp/ipykernel_2693/4052666499.py", line 6
#     print("addition="a+b)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
a=input("enter value of a")
b=input("enter value of b")
print("============")
print("sample calculator")
print("============")
print("addition=",a+b)
print("============")
'addition is wrong. so we have to perform type casting'


c=a+b
print(c)
# Out:
# enter value of a10
# enter value of b20
# ...
# sample calculator
# ...
# addition= 1020
# ...
# 1020

# %%
a=input("enter value of a")
b=input("enter value of b")
a=int(a)
b=int(b)
print("============")
print("sample calculator")
print("============")
print("addition=",a+b)
print("mul=",a*b)
print("sub=",a-b)
print("div=",a/b)
print("rem=",a%b)
print("============")
# Out:
# enter value of a10
# enter value of b20
# ...
# sample calculator
# ...
# addition= 30
# mul= 200
# sub= -10
# div= 0.5
# rem= 10
# ...
